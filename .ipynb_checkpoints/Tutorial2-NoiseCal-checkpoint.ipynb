# %%
import adpipy

# %%
help(adpipy.NoiseCal)
# Out:
# Help on module adpipy.NoiseCal in adpipy:
#
# NAME
#     adpipy.NoiseCal
#
# DESCRIPTION
#     Lead Developer: Timothy Yu
#     Email: tinyau.yu@outlook.com
#     Date: 2022.05.12
#
# CLASSES
#     adpipy.AlmaMap.AlmaMap(builtins.object)
#         AlmaMap_NoiseCal
#
#     class AlmaMap_NoiseCal(adpipy.AlmaMap.AlmaMap)
#      |  AlmaMap_NoiseCal(imagename='', region='', **kwargs)
#      |
#      |  A child class of AlmaMap class which computes the RMS noise of a non-primary beam corrected map or a region of the map
#      |
#      |  Parameters
#      |  ----------
#      |  imagename: str
#      |      The path to the FITS file
#      |
#      |  region: str
#      |      The path to the CASA region file with an extension of .crtf
#      |      Without region file, the default region is the whole map
#      |
#      |  kwargs:
#      |      The key arguments for CASA task - imval()
#      |      Only required when region file is specified
#      |
#      |
#      |  Attributes
# ...

# %%
help(adpipy.NoiseCal.AlmaMap_NoiseCal)
# Out:
# Help on class AlmaMap_NoiseCal in module adpipy.NoiseCal:
#
# class AlmaMap_NoiseCal(adpipy.AlmaMap.AlmaMap)
#  |  AlmaMap_NoiseCal(imagename='', region='', **kwargs)
#  |
#  |  A child class of AlmaMap class which computes the RMS noise of a non-primary beam corrected map or a region of the map
#  |
#  |  Parameters
#  |  ----------
#  |  imagename: str
#  |      The path to the FITS file
#  |
#  |  region: str
#  |      The path to the CASA region file with an extension of .crtf
#  |      Without region file, the default region is the whole map
#  |
#  |  kwargs:
#  |      The key arguments for CASA task - imval()
#  |      Only required when region file is specified
#  |
#  |
#  |  Attributes
#  |  ----------
#  |  self.region: str
#  |      The path to the region file
#  |
#  |  self.noise_pixel_dist: dict
#  |      The dictionary that stores the counts and pixel values of the pixel distribution which will be used to compute the RMS noise
#  |
#  |  self.noise_dist: dict
# ...

# %%
# define the FITS file path
FITSPATH = 'UV-171060.4spw.cont.image.fits'

# %%
UV_171060 = adpipy.NoiseCal.AlmaMap_NoiseCal(imagename=FITSPATH)
# Out:
# UV-171060.4spw.cont.image.fits is a ALMA Continuum Map
# CASA Region File is NOT provided...
# Extract RMS noise using the whole map...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 UV_171060 = adpipy.NoiseCal.AlmaMap_NoiseCal(imagename=FITSPATH)
#
# File ~/myvenv/lib/python3.8/site-packages/adpipy/NoiseCal.py:95, in AlmaMap_NoiseCal.__init__(self, imagename, region, **kwargs)
#      91     print('CASA Region File is NOT provided... \n'+'Extract RMS noise using the whole map...')
#      92     self.noise_pixel_dist = self.pixel_dist.copy()
# ---> 95 self.noise_dist = self.get_noise_dist()
#      96 self.rms = self.get_rms_noise()
#
# File ~/myvenv/lib/python3.8/site-packages/adpipy/NoiseCal.py:242, in AlmaMap_NoiseCal.get_noise_dist(self)
#     239 noise_dist = {'counts':noise_counts, 'vals':noise_pixelval}
# ...

# %%
UV_171060.rms
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 UV_171060.rms
#
# NameError: name 'UV_171060' is not defined
