# %% [markdown]
# ### First, import adpipy

# %%
import adpipy

# %%
help(adpipy)
# Out:
# Help on package adpipy:
#
# NAME
#     adpipy
#
# PACKAGE CONTENTS
#     AlmaMap
#     DetectSources
#     ExtractNSigmaRegions
#     NoiseCal
#     Photometry
#     utils (package)
#
# SUBMODULES
#     crtftools
#     plottools
#
# FILE
#     /Users/menorahlam/myvenv/lib/python3.8/site-packages/adpipy/__init__.py

# %% [markdown]
# View the DetectSources module

# %%
help(adpipy.DetectSources)
# Out:
# Help on class DetectSources in module adpipy.DetectSources:
#
# class DetectSources(adpipy.NoiseCal.AlmaMap_NoiseCal)
#  |  DetectSources(imagename='', region='', **kwargs)
#  |
#  |  This class uses segmentation and deblending modules from photutils to obtain detections from Alma continuum maps
#  |
#  |  Detected sources must have a minimum number of connected pixels that are each greater than a specified threshold value in an image.
#  |
#  |  Question 1: Considering threshold = bkg + (2.0 * bkg_rms) while the input image includes the background. How to determine the background of the image?
#  |  Question 2: How to define the number of connected pixels? (Not smaller than a fraction of the number of pixels inside a synthesis beam)
#  |  Question 3: When do we need to convolve the data and smooth the image?
#  |
#  |
#  |  Parameters
#  |  ----------
#  |  imagename: str
#  |      The path to the FITS file of an Alma continuum map
#  |
#  |  region: str
# ...

# %% [markdown]
# Define the data path

# %%
DATAPATH = "../UV-171060.2d.image.fits"

# %%
ds = adpipy.DetectSources(imagename=DATAPATH)
# Out:
# ../UV-171060.2d.image.fits is a 2D ALMA Continuum Map. It doesn't have frequency channels - NAXIS3
# CASA Region File is NOT provided...
# Extract RMS noise using the whole map...
# RMS Calculation Results:
# -------------------------------
# RMS Noise Estimation using Least Square Curve Fitting
# RMS Noise = 1.91e-05 +/- 1.22e-07 [Jy/beam]
# -------------------------------
# Goodness of fit statistics
# R2 = 9.96e-01
# ../UV-171060.2d.image.fits is a 2D ALMA Continuum Map. It doesn't have frequency channels - NAXIS3
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58248.993366 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -67.754929 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -23.022886 from OBSGEO-[XYZ].
# Set OBSGEO-H to     5053.796 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# Reference frequency is required to plot the primary beam...
# Cannot plot the primary beam...
# ...

# %%
ds.wcs.naxis
# Out:
# 2
